# %%
import time
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('chicago.csv')

# %%
i = 0
while True:   
    data = input('\nDo you want to view the Raw Data? Enter yes or no.\n').lower()
    if data == 'yes':
        j = i+5
        print (df.iloc[i:j])
        i =i+5
    else:
        print('ok')
        break

# %%
i = 5
j = i+5
df.iloc[i:j]

# %%
while True:
    city = input('Enter the city:chicago,washington,newyork')
    if city not in  ['chicago', 'washington' , 'newyork' ]:
        print('wrong city')
    else:
        print('you selected : ' + city)
        break

# %%
while True:
        day = input('Select the day : all or sun, mon ,tue,wed,thu,fri,sat,sun')
        print(/n)
        if day in ['all','sun','mon','tue','wed','thu','fri','sat','sun']:
            print ('You selected {} day'.format(day))
            break
        else:
            print('Select again')

# %%
df.count()
# Out:
# Unnamed: 0       300000
# Start Time       300000
# End Time         300000
# Trip Duration    300000
# Start Station    300000
# End Station      300000
# User Type        300000
# Gender           238948
# Birth Year       238981
# dtype: int64

# %%
df['combination'] ='From ' + df['Start Station'] +' Till '+ df['End Station']
df['combination'].mode()

# %%
# Out:
# 0    From Lake Shore Dr & Monroe St Till Streeter D...
# dtype: object

# %%
df['Start Time'] = pd.to_datetime(df['Start Time'], errors='raise')

# %%
df['End Station'].count()
# Out:
# 300000

# %%
df['Start Station'].count()
# Out:
# 300000

# %%
def station_stats(df):
    """Displays statistics on the most popular stations and trip."""

    print('\nCalculating The Most Popular Stations and Trip...\n')
    start_time = time.time()

    # display most commonly used start station
    print ('Most commonly used start station is : ' , df['Start Station'].mode()[0])


    # display most commonly used end station
    print ('Most commonly used end station is : ' , df['End Station'].mode()[0])


    # display most frequent combination of start station and end station trip
    df1 = pd.concat([df['Start Station'], df['End Station']])
    print('Most frequent combination station for Start and End Trip : ' , df1.mode()[0])


    print("\nThis took %s seconds." % (time.time() - start_time))
    print('-'*40)
station_stats(df)
# Out:
# Calculating The Most Popular Stations and Trip...
#
# Most commonly used start station is :  Streeter Dr & Grand Ave
# Most commonly used end station is :  Streeter Dr & Grand Ave
# Most frequent combination station for Start and End Trip :  Streeter Dr & Grand Ave
#
# This took 0.3008289337158203 seconds.
# ----------------------------------------

# %%
df['hour'] = df['Start Time'].dt.hour
df['month'] = df['Start Time'].dt.month
df['day_of_week'] = df['Start Time'].dt.weekday_name

# %%
df['month'].unique()
# Out:
# array([6, 5, 1, 3, 4, 2], dtype=int64)

# %%
df['day_of_week'].unique()
# Out:
# array(['Friday', 'Thursday', 'Wednesday', 'Monday', 'Tuesday', 'Saturday',
#        'Sunday'], dtype=object)

# %%
day = 'friday'
df[df['day_of_week'] == day.title]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Start Time, End Time, Trip Duration, Start Station, End Station, User Type, Gender, Birth Year, month, day_of_week]
# Index: []

# %%
popular_hour = df['hour'].mode()

# %%
print('Most Frequent Start Hour:',17)

# %%
import pandas as pd

filename = 'chicago.csv'

# load data file into a dataframe
df = pd.read_csv(filename)

# print value counts for each user type
user_types = df['User Type'].value_counts()

print(user_types)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Start Time', 'End Time', 'Trip Duration',
#        'Start Station', 'End Station', 'User Type', 'Gender', 'Birth Year'],
#       dtype='object')

# %%
df['User Type'].unique()
# Out:
# array(['Subscriber', 'Customer', 'Dependent'], dtype=object)

# %%
df['User Type'].value_counts()
# Out:
# Subscriber    238889
# Customer       61110
# Dependent          1
# Name: User Type, dtype: int64

# %%
import pandas as pd

CITY_DATA = { 'chicago': 'chicago.csv',
              'new york city': 'new_york_city.csv',
              'washington': 'washington.csv' }

def load_data(city, month, day):
    """
    Loads data for the specified city and filters by month and day if applicable.

    Args:
        (str) city - name of the city to analyze
        (str) month - name of the month to filter by, or "all" to apply no month filter
        (str) day - name of the day of week to filter by, or "all" to apply no day filter
    Returns:
        df - Pandas DataFrame containing city data filtered by month and day
    """

    # load data file into a dataframe
    df = pd.read_csv(CITY_DATA[city])

    # convert the Start Time column to datetime
    df['Start Time'] = pd.to_datetime(df['Start Time'])

    # extract month and day of week from Start Time to create new columns
    df['month'] = df['Start Time'].dt.month
    df['day_of_week'] = df['Start Time'].dt.weekday_name

    # filter by month if applicable
    if month != 'all':
        # use the index of the months list to get the corresponding int
        months = ['january', 'february', 'march', 'april', 'may', 'june']
        month = months.index(month) + 1

        # filter by month to create the new dataframe
        df = df[df['month'] == month]

    # filter by day of week if applicable
    if day != 'all':
        # filter by day of week to create the new dataframe
        df = df[df['day_of_week'] == day.title()]

    return df
df = load_data('chicago', 'march', 'friday')
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0,
# 66      Subscriber    Male      1991.0      5      Friday
# 77      Subscriber    Male      1963.0      5      Friday
# 115     Subscriber    Male      1991.0      5      Friday
# 131     Subscriber    Male      1993.0      5      Friday
# 144     Subscriber    Male      1990.0      5      Friday
# 207     Subscriber  Female      1962.0      5      Friday
# 217     Subscriber    Male      1970.0      5      Friday
# 238     Subscriber    Male      1993.0      5      Friday
# 250     Subscriber    Male      1962.0      5      Friday
# 263     Subscriber    Male      1968.0      5      Friday
# 309     Subscriber  Female      1991.0      5      Friday
# 320     Subscriber    Male      1985.0      5      Friday
# 399     Subscriber    Male      1968.0      5      Friday
# 413     Subscriber  Female      1991.0      5      Friday
# 444     Subscriber    Male      1985.0      5      Friday
# 464     Subscriber    Male      1988.0      5      Friday
# 466     Subscriber    Male      1989.0      5      Friday
# 561       Customer     NaN         NaN      5      Friday
# 600     Subscriber    Male      1979.0      5      Friday
# 628     Subscriber    Male      1987.0      5      Friday
# 743     Subscriber    Male      1989.0      5      Friday
# 766     Subscriber    Male      1989.0      5      Friday
# 778     Subscriber    Male      1994.0      5      Friday
# 874       Customer     NaN         NaN      5      Friday
# 923     Subscriber    Male      1990.0      5      Friday
# 932       Customer     NaN         NaN      5      Friday
# 984     Subscriber  Female      1957.0      5      Friday
# 1021    Subscriber    Male      1979.0      5      Friday
# ...            ...     ...         ...    ...         ...
# 298857  Subscriber    Male      1991.0      5      Friday
# 298859  Subscriber    Male      1990.0      5      Friday
# 298905  Subscriber    Male      1988.0      5      Friday
# 298971  Subscriber    Male      1950.0      5      Friday
# 299079    Customer     NaN         NaN      5      Friday
# 299105    Customer     NaN         NaN      5      Friday
# 299147  Subscriber    Male      1971.0      5      Friday
# 299173  Subscriber    Male      1981.0      5      Friday
# 299178    Customer     NaN         NaN      5      Friday
# 299185  Subscriber  Female      1984.0      5      Friday
# 299214  Subscriber    Male      1990.0      5      Friday
# 299297  Subscriber    Male      1974.0      5      Friday
# 299311  Subscriber  Female      1986.0      5      Friday
# 299432  Subscriber    Male      1975.0      5      Friday
# 299437    Customer     NaN         NaN      5      Friday
# 299458  Subscriber    Male      1988.0      5      Friday
# 299474  Subscriber    Male      1977.0      5      Friday
# 299581    Customer     NaN         NaN      5      Friday
# 299617  Subscriber    Male      1963.0      5      Friday
# 299659  Subscriber    Male      1983.0      5      Friday
# 299661  Subscriber    Male      1984.0      5      Friday
# 299763  Subscriber  Female      1958.0      5      Friday
# 299768  Subscriber  Female      1968.0      5      Friday
# 299770  Subscriber  Female      1992.0      5      Friday
# 299779  Subscriber  Female      1978.0      5      Friday
# 299900  Subscriber    Male      1962.0      5      Friday
# 299931  Subscriber    Male      1980.0      5      Friday
# 299949  Subscriber    Male      1990.0      5      Friday
# 299951  Subscriber  Female      1982.0      5      Friday
# 299962  Subscriber    Male      1990.0      5      Friday
#
# [7090 rows x 11 columns]

# %%
df['day_of_week'].mode()
# Out:
# 0    Friday
# dtype: object

# %%
import pandas as pd

CITY_DATA = { 'chicago': 'chicago.csv',
              'new york city': 'new_york_city.csv',
              'washington': 'washington.csv' }

def load_data(city, month, day):
    """
    Loads data for the specified city and filters by month and day if applicable.

    Args:
        (str) city - name of the city to analyze
        (str) month - name of the month to filter by, or "all" to apply no month filter
        (str) day - name of the day of week to filter by, or "all" to apply no day filter
    Returns:
        df - Pandas DataFrame containing city data filtered by month and day
    """

    # load data file into a dataframe
    df = pd.read_csv(CITY_DATA[city])

    # convert the Start Time column to datetime
    df['Start Time'] = pd.to_datetime(df['Start Time'])

    # extract month and day of week from Start Time to create new columns
    df['month'] = df['Start Time'].dt.month
    df['day_of_week'] = df['Start Time'].dt.weekday_name

    # filter by month if applicable
    if month != 'all':
        # use the index of the months list to get the corresponding int
        months = ['january', 'february', 'march', 'april', 'may', 'june']
        month = months.index(month) + 1

        # filter by month to create the new dataframe
        df = df[df['month'] == month]

    # filter by day of week if applicable
    if day != 'all':
        # filter by day of week to create the new dataframe
        df = df[df['day_of_week'] == day.title()]

    return df
df = load_data('chicago', 'march', 'friday')
